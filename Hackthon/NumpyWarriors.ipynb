# %%
# importing required packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# 1.Make a pair plot on Readmission Registry table & do u see any correlation between columns values.
# loading dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df_RA = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
# draw pair plot
sns.pairplot(df_RA)
plt.show()

# %%
#Q2 Using iloc, retrieve the firstname and lastname of patients between indices 101 and 200.
# loading dataset
df = pd.DataFrame(pd.read_excel("HospitalDatabase .xlsx"))
#retrieving the firstname and lastname using iloc
df.iloc[101:200,1:3]
# Out:
#     FirstName    LastName
# 101     Gipsy    Frankton
# 102    Jethro      Wharin
# 103       Viv     Aylward
# 104     Swift   Dreschler
# 105     Fadel  Jacquemard
# ..        ...         ...
# 195  Cathlene     Kidwell
# 196      Noam    Laguerre
# 197      Arie     Bayless
# 198    Janaye     O'Mohun
# 199      Fonz       Group
#
# [99 rows x 2 columns]

# %%
#Q3 Create a figure object called fig using plt.figure() **
df = pd.DataFrame(pd.read_excel("HospitalDatabase .xlsx"))
fig =plt.figure(figsize=(10,7))
plt.plot(df.Gender , color = 'yellow')
plt.xlabel('PatientID')
plt.ylabel('Gender')
plt.title('Plot using figure object')
plt.show()

# %%
#Q4 Display data by splitting age in 4 quartiles and labeling the quartiles
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")
from dateutil.relativedelta import relativedelta
df['age'] = [relativedelta(pd.Timestamp.now(), d).years for d in df['DateOfBirth']]
df['QuantileRank']= pd.qcut(df['age'],
                             q = 4, labels = ['Q1','Q2','Q3','Q4'])
df
# Out:
#      PatientID FirstName  LastName             DateOfBirth Gender  \
# 0            1     Lanni       Sue 1960-01-01 00:00:00.000   Male
# 1            2       Far     Myers 1985-11-15 02:08:42.090   Male
# 2            3   Devlin    Michael 1976-04-15 02:52:09.762   Male
# 3            4   Carmine     Texas 1968-10-15 03:32:13.635   Male
# 4            5     Tann       Bama 1962-05-01 19:12:58.950   Male
# ..         ...       ...       ...                     ...    ...
# 940        941       Wat   Fideler 1986-05-26 00:01:19.761   Male
# 941        942    Wandie  Baythrop 1970-06-10 21:41:03.814   Male
# 942        943   Diahann   Smeeton 1983-01-08 21:49:27.884   Male
# 943        944  Panchito   Sharple 1963-06-05 07:57:05.569   Male
# 944        945     Walsh    Calvie 1972-08-06 03:40:03.454   Male
#
#                        Race Language  age QuantileRank
# 0                     White  English   62           Q4
# 1                     White  English   36           Q1
# ...

# %%
#Q5 Display full name of patients who are born in 1986.
import datetime as dt
df = pd.DataFrame(pd.read_excel("HospitalDatabase .xlsx"))
df["FullName"] = df["FirstName"] +' ' + df["LastName"]
df['Date'] = pd.to_datetime(df['DateOfBirth'])
df1=df[df['Date']. dt. strftime('%Y')=='1986']
df2=df1[['FullName','DateOfBirth']]
df2
# Out:
#                 FullName             DateOfBirth
# 23       Gabriel  Joseph 1986-05-31 09:36:05.716
# 24       Lincoln  Brenda 1986-07-24 17:36:00.791
# 29           Ala Halpert 1986-11-26 10:44:22.628
# 72          Lolita Darci 1986-01-08 02:34:04.596
# 164       Fadel Bernardt 1986-05-29 00:35:58.694
# 238       Bentley Kippax 1986-02-11 06:22:40.734
# 367          Vale Olanda 1986-04-15 00:49:58.690
# 373        Britt Dureden 1986-11-19 23:50:47.955
# 386     Cristabel Chatel 1986-07-10 16:27:30.640
# 415     Constantia Group 1986-03-26 06:37:22.525
# 452     Morgan Scrowston 1986-12-19 21:34:24.472
# 561           Dom Baglow 1986-07-26 14:43:49.240
# 568      Ignazio Melling 1986-12-25 03:40:43.884
# 595       Homenick Rings 1986-02-24 15:08:30.404
# 639         Hashim Slark 1986-10-13 10:40:43.596
# 643     Ellie Ramsbotham 1986-05-21 16:35:52.711
# 674      Llewellyn Group 1986-11-09 17:15:11.196
# 714           Niles Shaw 1986-12-15 06:31:44.358
# ...

# %%
#6.Create a jointplot on expected mortality & expected length of stay.
# loading dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
# draw jointplot with
# Hist kind
sns.jointplot(x = "ExpectedMortality", y = "ExpectedLOS" ,
              kind = "hist", data = df , color = 'orange')
# show the plot
plt.show()

# %%
#7.Create a pair plot on whole dataframe by taking parameter "hue" as EDDisposition.
# loading dataset using pandas
df_ED = pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDUnique")
# pairplot with hue EDDisposition
sns.pairplot(df_ED, hue ='EDDisposition',palette='bright')
# to show
plt.show()

# %%
#8.Create a bar chart between expectedLOS & Primary diagnosis.
# loading dataset using Pandas
df= pd.read_excel("HospitalDatabase .xlsx",sheet_name="Discharges")
LOS = df['ExpectedLOS']
PD = df['PrimaryDiagnosis']

# Figure Size
fig = plt.figure(figsize = (25, 7))

# creating the bar plot
plt.xlabel("PrimaryDiagnosis")
plt.ylabel("ExpectedLOS")
plt.title("PrimaryDiagnosis wise ExpectedLOS ")
plt.bar(PD,LOS,color='maroon',width=0.5)
plt.grid(color = 'black', alpha = 0.3, linestyle = '-', linewidth = 2)
#TO Show
plt.show()

# %%
#9.Get the list of patient ID's which are not there in ReadmissionRegistry.

#loading Patients Dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")
#Creating new dataframe with unique patient ids in patients dataset
DF_P= df['PatientID'].unique()

#Loading ReadmissionRegistry Dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
#Creating new dataframe with unique patient ids in ReAdmissionRegistry dataset
DF_RARP = df['PatientID'].unique()

#Getting Patients list

def non_match_Patients(DF_P, DF_RARP):
    non_match = []
    for i in DF_P:
        if i not in DF_RARP:
            non_match.append(i)
    return non_match

non_match = non_match_Patients(DF_P, DF_RARP)
print("list of patient ID's which are not there in ReadmissionRegistry: ", non_match)

print("Total Patients which are not there in ReadmissionRegistry :",len(non_match))
# Out:
# list of patient ID's which are not there in ReadmissionRegistry:  [4, 135, 145, 189, 200, 224, 234, 374, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 414, 501, 562, 599, 690, 691, 704, 726, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 861, 862, 863, 864, 865, 866, 867, 868, 869, 870, 871, 872, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891
# ...

# %%
#10.Create a boxplot on ExpectedLOS by taking service into account.
#Loading Dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
#Boxplot
sns.catplot(x='Service', y='ExpectedLOS',
                data=df, kind="box",
            height=6, aspect=1.3);

# %%
# 11. Create a pie chart by taking Service= ["ICU", "Neurology", "General", "Medicine"] & ExpectedLOS=[10,5,7,9] &
#     explode the wedge with highest LOS.
# loading dataset using pandas

y = np.array([10, 5, 7,9])
LblServ = ["ICU", "Neurologist","General","Medicine"]
myexplode = [0.2,0, 0, 0]

plt.title("Pie Chart Services and Expected LOS")
plt.pie(y)
plt.pie(y, labels = LblServ)
plt.pie(y, labels = LblServ, explode = myexplode)
plt.show()

# %%
"""12.Connect to sql and write a query to get list of Provider names whose Providername is starting with letter T.
pre requsites to connect to postgressql
run these 3 pip commands in command prompt

py -m pip install sqlalchemy
py -m pip install ipython-sql
py -m pip install psycopg2

run below code of line in a seperate cell in jupyter notes or pycharm IDE for conda installation
conda install -c conda-forge ipython-sql

After all above packages are installed and no error run following code """

from sqlalchemy import create_engine
# !pip install psycopg2-binary
engine = create_engine('postgresql://postgres:password@localhost:5432/HospitalDB_New')
#%sql dialect+driver://username:password@host:port/database
'Connected: postgres@HospitalDB_New'

# %load_ext sql
# %sql $engine.url
# %sql select "ProviderName" from public."Providers" where "ProviderName" like 'T%'
# Out:
# ...
#
#   %reload_ext sql
#  * postgresql://postgres:***@localhost:5432/HospitalDB_New
# 6 rows affected.
# [('Ted Texas',),
#  ('Ted Green',),
#  ('Ted Black',),
#  ('Tyler Conner',),
#  ('Tony Creed',),
#  ('Trent Tye',)]

# %%
# 13. Create a subplot on x = np.arange(0, 10, 0.1) , y = np.sin(np.pi * x) + x with 2 rows & 2 columns
#     with object oriented approach.
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.1)
y = np.sin(np.pi * x) + x

# passing 2,2 as parameters indicates that you will
# get 4 subplots (2 rows and 2 columns)

fig, ax = plt.subplots(2,2)

ax[0][0].scatter(x,y,c='red')
#ax[0][1].plot(x,y)
ax[0][1].bar(x,y)

ax[1][0].barh(x,y,)
ax[1][1].plot(x,y)

# %%
#14. Find the number of null values in BloodPressureSystolic column.
# loading dataset using pandas
df_Ans14 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="AmbulatoryVisits")
#df_Ans14[df_Ans14['BloodPressureSystolic'].isnull()]
count_NaN = df_Ans14['BloodPressureSystolic'].isna().sum()
print ('Number of null values in BloodPressureSystolic column  =  ' + str(count_NaN))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [239], in <cell line: 6>()
#       4 #df_Ans14[df_Ans14['BloodPressureSystolic'].isnull()]
#       5 count_NaN = df_Ans14['BloodPressureSystolic'].isna().sum()
# ----> 6 print ('Number of null values in BloodPressureSystolic column  =  ' + str(count_NaN))
#
# TypeError: 'str' object is not callable

# %%
# 15 .Replace all the null values in ReadmissionFlag with 0.
# loading dataset using pandas
df_Ans15 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
df_Ans15["ReadmissionFlag"].fillna("0", inplace = True)
df_Ans15
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0            389          1    2018-01-01 2018-01-04 19:59:31.391
# 1            635          2    2018-01-01 2018-01-04 21:28:51.898
# 2            606          3    2018-01-01 2018-01-04 22:28:23.672
# 3            587          5    2018-01-01 2018-01-05 05:47:04.933
# 4            640          6    2018-01-01 2018-01-05 14:18:30.029
# ..           ...        ...           ...                     ...
# 715          521        738    2018-02-22 2018-03-07 21:22:10.061
# 716          548        739    2018-02-22 2018-03-08 02:43:18.749
# 717          509        740    2018-02-22 2018-03-08 09:27:18.377
# 718          605        741    2018-02-22 2018-03-10 06:06:12.068
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#     DischargeDisposition           Service PrimaryDiagnosis  ExpectedLOS  \
# 0                   Home       Hospitalist   Kidney Failure     6.717771
# ...

# %%
# 16. Plot a graph to show the distribution of expected length of stay.
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name="ReAdmissionRegistry")
# set the background style of the plot
sns.set_style('whitegrid')
sns.displot(df1['ExpectedLOS'], kde = False, color ='green', bins = 15)
plt.ylabel("Count of Patients")
plt.title("Distribution of Expected length of stay")
# Out:
# Text(0.5, 1.0, 'Distribution of Expected length of stay')

# %%
#Q17 Create a heat map to show the correlation between the column values of Edvisits.
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb
data=pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDVisits")
#print(data.corr())
dataplot = sb.heatmap(data.corr(), cmap="YlGnBu", annot=True)
mp.show()

# %%
#Q18 Add column 'Age' in Patient table.
import pandas as pd
df = pd.DataFrame(pd.read_excel("HospitalDatabase .xlsx"))
from dateutil.relativedelta import relativedelta
df['Age'] = [relativedelta(pd.Timestamp.now(), d).years for d in df['DateOfBirth']]
df
# Out:
#      PatientID FirstName  LastName             DateOfBirth Gender  \
# 0            1     Lanni       Sue 1960-01-01 00:00:00.000   Male
# 1            2       Far     Myers 1985-11-15 02:08:42.090   Male
# 2            3   Devlin    Michael 1976-04-15 02:52:09.762   Male
# 3            4   Carmine     Texas 1968-10-15 03:32:13.635   Male
# 4            5     Tann       Bama 1962-05-01 19:12:58.950   Male
# ..         ...       ...       ...                     ...    ...
# 940        941       Wat   Fideler 1986-05-26 00:01:19.761   Male
# 941        942    Wandie  Baythrop 1970-06-10 21:41:03.814   Male
# 942        943   Diahann   Smeeton 1983-01-08 21:49:27.884   Male
# 943        944  Panchito   Sharple 1963-06-05 07:57:05.569   Male
# 944        945     Walsh    Calvie 1972-08-06 03:40:03.454   Male
#
#                        Race Language  Age
# 0                     White  English   62
# 1                     White  English   36
# 2                     White  English   46
# ...

# %%
#Q19 Create a dataframe with date and time as columns, where the values are the discharge time from readmissionregistry sheet.
import datetime
df= pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
df['Date'] = pd.to_datetime(df['DischargeDate']).dt.date
df['Time'] = pd.to_datetime(df['DischargeDate']).dt.time
df
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0            389          1    2018-01-01 2018-01-04 19:59:31.391
# 1            635          2    2018-01-01 2018-01-04 21:28:51.898
# 2            606          3    2018-01-01 2018-01-04 22:28:23.672
# 3            587          5    2018-01-01 2018-01-05 05:47:04.933
# 4            640          6    2018-01-01 2018-01-05 14:18:30.029
# ..           ...        ...           ...                     ...
# 715          521        738    2018-02-22 2018-03-07 21:22:10.061
# 716          548        739    2018-02-22 2018-03-08 02:43:18.749
# 717          509        740    2018-02-22 2018-03-08 09:27:18.377
# 718          605        741    2018-02-22 2018-03-10 06:06:12.068
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#     DischargeDisposition           Service PrimaryDiagnosis  ExpectedLOS  \
# 0                   Home       Hospitalist   Kidney Failure     6.717771
# ...

# %%
#Q20 Count of number of patients admitted based on Primary Diagnosis and Service provided.
df= pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
df=df.groupby(["PrimaryDiagnosis", "Service"]).size().reset_index(name="Number of Patients Admitted")
df
# Out:
#       PrimaryDiagnosis           Service  Number of Patients Admitted
# 0                  AMI        Cardiology                           40
# 1                  AMI       Hospitalist                            1
# 2                  AMI               ICU                            5
# 3                  AMI         Neurology                            2
# 4                 Afib        Cardiology                           10
# 5                 Afib               ICU                            1
# 6           Broken Leg        Cardiology                            3
# 7           Broken Leg  General Medicine                            3
# 8           Broken Leg       Hospitalist                            3
# 9             Diabetes  General Medicine                           38
# 10            Diabetes       Hospitalist                           26
# 11               Fever  General Medicine                           13
# ...

# %%
# Q21 Which demographic patients are prone to get stroke.
df1 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
df2= pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")
df3 = df2.merge(df1, on='PatientID', how='inner', indicator=True)
df4=df3[df3["PrimaryDiagnosis"]=='Stroke']
df5=df4[['PatientID','Race','PrimaryDiagnosis']]
df5
# Out:
#      PatientID                    Race PrimaryDiagnosis
# 8           10                   White           Stroke
# 12          14                   White           Stroke
# 18          19                   White           Stroke
# 34          30                   White           Stroke
# 40          35                   White           Stroke
# ..         ...                     ...              ...
# 581        601  Black/African-American           Stroke
# 582        602  Black/African-American           Stroke
# 591        611  Black/African-American           Stroke
# 622        642  Black/African-American           Stroke
# 652        672                   White           Stroke
#
# [68 rows x 3 columns]

# %%
#22	Create a dataframe with acuity and EDDisposition as the indices and the count of number of patients as the value.
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='EDVisits')
df = df2.groupby(['Acuity','EDDisposition']).size().reset_index(name='PatientCount')
df1=pd.DataFrame(df)
# set Acuity & EDDisposition as index of the dataframe
df1=df1.set_index(['Acuity','EDDisposition'])
print(df1)
# Out:
#                       PatientCount
# Acuity EDDisposition
# 1      Admitted                 32
#        Discharged              558
# 2      Admitted                116
#        Discharged               66
# 3      Admitted                 81
# 4      Admitted                107
#        Discharged               30
# 5      Admitted                179
#        Discharged               30

# %%
#23 write a function to find the center element in the list. (one element in odd length list,  two elements in even length list)
def findMiddle(input_list):
    middle = float(len(input_list))/2
    if ((middle % 2 )!= 0):
        return input_list[int(middle - .5)]
    else:
        return ([input_list[int(middle-1)], input_list[int(middle)]])


input_string= input("Enter a list element separated by space: ")
list  = input_string.split()
print(list)
findMiddle(list)
# Out:
# ['k', 'a', 'l']
# 'a'

# %%
#24	Get the number of patients based on ReasonForVisit and EDDisposition (use stack/unstack functions).
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='EDVisits')
PatientCount = df2.groupby(['ReasonForVisit','EDDisposition'])['PatientID'].count().reset_index(name='Pt_Count')

print(PatientCount.stack(0))
print(PatientCount.unstack(level=1))
# Out:
# 0   ReasonForVisit               Accident
#     EDDisposition                Admitted
#     Pt_Count                           39
# 1   ReasonForVisit               Bleeding
#     EDDisposition                Admitted
#     Pt_Count                           16
# 2   ReasonForVisit               Bleeding
#     EDDisposition              Discharged
#     Pt_Count                           15
# 3   ReasonForVisit           Car Accident
#     EDDisposition                Admitted
#     Pt_Count                           17
# 4   ReasonForVisit             Chest Pain
#     EDDisposition                Admitted
#     Pt_Count                           94
# 5   ReasonForVisit             Chest Pain
#     EDDisposition              Discharged
#     Pt_Count                           15
# 6   ReasonForVisit                  Cough
#     EDDisposition              Discharged
#     Pt_Count                            1
# 7   ReasonForVisit                  Fever
# ...

# %%
# 25 Plot a graph by counting the no. of patients in each department.
#loading data into dataframe
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='ReAdmissionRegistry')
df2 = df2.groupby(['Service']).size().reset_index(name='Count')
#sorting based on count
df2 = df2.sort_values('Count')
#Plotting a bar graph
sns.barplot(x="Service", y="Count", data=df2, palette=sns.color_palette("GnBu", 10))
plt.title("Plot of no. of patients in each department")
# Out:
# Text(0.5, 1.0, 'Plot of no. of patients in each department')

# %%
#26 . Using arrays and loops, find the count of patients based on gender.
df= pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")
df.Gender.value_counts().reset_index(name='Patients based on gender')
# Out:
#     index  Patients based on gender
# 0    Male                       537
# 1  Female                       408

# %%
#27.Plot a graph to count the patients based on discharge disposition.
#Loadind dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Discharges")
#Creating new dataframe for groups
df_gb = df.groupby(['DischargeDisposition'])['PatientID'].count()

#Plot Graph
plt.ylabel("Number Of Patients")
plt.title("count the patients based on discharge disposition ")
df_gb.plot(kind = 'bar',color = 'purple')
# Out:
# <AxesSubplot:title={'center':'count the patients based on discharge disposition '}, xlabel='DischargeDisposition', ylabel='Number Of Patients'>

# %%
#28.Which reason of visit has maximum mortality rate.
#Loading datasets
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDVisits")
df1 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Discharges")
#Combining two datasets
df2 = pd.concat([df, df1], axis=1, join='inner')
new_df = df2[['ReasonForVisit','ExpectedMortality']].copy()
df3 = new_df.sort_values(by=['ExpectedMortality'])
df3.tail(1)
# Out:
#    ReasonForVisit  ExpectedMortality
# 88     Chest Pain           0.989945

# %%
#29.Calculate average LOS.

#Loadind dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Discharges")

#Calucalate Avg or mean

df2 = df["ExpectedLOS"].mean()
print("Average LOS : ",df2)
# Out:
# Average LOS :  8.82458915915616

# %%
#30.Which patient id has most entries in readmission registry.
#Loading Dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")

#Prints patient id that has most entries
df["PatientID"].mode()
# Out:
# 0    23
# Name: PatientID, dtype: int64

# %%
#31. Find the count of White Spanish Male.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")

#Creating new dataframe for group

df['Gender']=df['Gender'].mask(df['Gender'].ne('Male'))
df['Race']=df['Race'].mask(df['Race'].ne('White'))
df['Language']=df['Language'].mask(df['Language'].ne('Spanish'))
df.groupby(['Gender','Race','Language']).size()
# Out:
# Gender  Race   Language
# Male    White  Spanish     15
# dtype: int64

# %%
#31. Find the count of White Spanish Male.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")
df_g = df.query('Gender == "Male"  & Race=="White" & Language == "Spanish"')
print("count of White Spanish Male: ",len(df_g))
# Out:
# count of White Spanish Male:  15

# %%
# 32. Write a function to print the multipication table of the given number.

# Create Multiplication_table- function which prints multiplication table of a given number
def Multiplication_table(num):
       for i in range(1,11):
        print(num,' x ', i, ' = ',num*i)

# end of function Multiplication_table

# input a number

n = int(input("Please Enter a number to print its multiplication table:"))

 # call the function table by passing actual parameter 'n'

Multiplication_table(n)
# Out:
# 9  x  1  =  9
# 9  x  2  =  18
# 9  x  3  =  27
# 9  x  4  =  36
# 9  x  5  =  45
# 9  x  6  =  54
# 9  x  7  =  63
# 9  x  8  =  72
# 9  x  9  =  81
# 9  x  10  =  90

# %%
#Q33 Using a bar chart, which Service had the lowest count of Expected Mortality?
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
#Finding the count of expected Mortality by service and sorting it
df=df.groupby('Service')['ExpectedMortality'].size().reset_index(name='Count').sort_values('Count',ascending=False)
#Plot horizontal bars
df.plot(kind="barh",figsize=(10, 7), x='Service',y='Count',title='Service with lowest count of Expected Mortality',color='red')
# Conclusion : Orthopedics had the lowest count of Expected Mortality
# Out:
# <AxesSubplot:title={'center':'Service with lowest count of Expected Mortality'}, ylabel='Service'>

# %%
#Q34 np.arange(1,31).reshape(6,5) Find the array slicing to get the elements with values 11,12,16,17.
import numpy as np
data = np.arange(1,31)
arr = np.arange(1,31).reshape(6, 5)
arr2 = arr[2:,:2]
arr3=arr2[:2]
print(arr3)
# Out:
# [[11 12]
#  [16 17]]

# %%
#35 np.arange(1,31).reshape(6,5), find array slicing for elements 2,8,14,20
import numpy as np
data = np.arange(1,31)
arr = np.arange(1,31).reshape(6, 5)
arr2 = arr[0:4,1:5]
arr3=np.diag(arr2)
arr3
# Out:
# array([ 2,  8, 14, 20])

# %%
#36 Create a correlation matrix on EDVisits
import seaborn as sn
import matplotlib.pyplot as plt
dataframe = pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDVisits")
corrMatrix = dataframe.corr()
print(corrMatrix)
# Out:
#            EDVisitID  PatientID    Acuity
# EDVisitID   1.000000   0.975477  0.005813
# PatientID   0.975477   1.000000  0.003545
# Acuity      0.005813   0.003545  1.000000

# %%
#37	Write a function to print all the upper case letter of a given sentence.

# initializing string
input_string= input("Enter a sentence ")

# printing original string
print("The original string is : " + str(input_string))

# Extract Upper Case Characters
# Using list comprehension + isupper()
res = [char for char in input_string if char.isupper()]

# printing result
print("The uppercase characters in string are : " , res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [263], in <cell line: 7>()
#       4 input_string= input("Enter a sentence ")
#       6 # printing original string
# ----> 7 print("The original string is : " + str(input_string))
#       9 # Extract Upper Case Characters
#      10 # Using list comprehension + isupper()
#      11 res = [char for char in input_string if char.isupper()]
#
# TypeError: 'str' object is not callable

# %%
# 38.Number of patients on 'Transfer' based on primary diagnosis.
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='ReAdmissionRegistry')
df_count = df2.groupby('PrimaryDiagnosis')['DischargeDisposition'].apply(lambda x: (x=='Transfer').sum()).reset_index(name='TransferPatientCount')
print(df_count)
# Out:
#       PrimaryDiagnosis  TransferPatientCount
# 0                  AMI                     0
# 1                 Afib                     1
# 2           Broken Leg                     0
# 3             Diabetes                     7
# 4                Fever                     0
# 5                  Flu                     2
# 6        Heart Failure                     9
# 7         Hip Fracture                     0
# 8         Hypertension                     0
# 9       Kidney Failure                     0
# 10    Knee Replacement                     1
# 11          Laceration                     1
# 12            Migraine                     0
# 13                Pain                     1
# 14           Pneumonia                     8
# 15  Spinal Cord Injury                     0
# 16              Stroke                     9

# %%
# 39. Get the FirstName,LastName, DateOfBirth of the Patients whose reason for visit is Migraine. Use EDUnique Sheet for reason for visit.
df1 = pd.read_excel('HospitalDatabase .xlsx', sheet_name='Patients' )
df2=pd.read_excel('HospitalDatabase .xlsx',sheet_name = 'EDUnique')
cd = df2.merge(df1, on='PatientID', how='inner', indicator=True)
cd['DateOfBirth'] = pd.to_datetime(cd['DateOfBirth']).dt.date
cd1=cd[cd['ReasonForVisit']=='Migraine']


cd1[['FirstName','LastName','DateOfBirth','ReasonForVisit']]
# Out:
#     FirstName  LastName DateOfBirth ReasonForVisit
# 1      Zonnya        Ab  1963-05-23       Migraine
# 3         Gan        Yu  1970-06-02       Migraine
# 22    Devlin    Michael  1976-04-15       Migraine
# 44     Joesph      Long  1979-12-04       Migraine
# 46   Gabriel     Joseph  1986-05-31       Migraine
# ..        ...       ...         ...            ...
# 908     Hauck   Rubbens  1963-11-16       Migraine
# 921   Barrows  Coupland  1979-10-31       Migraine
# 928      Knox     Group  1975-08-25       Migraine
# 930   Kuvalis  Coupland  1986-05-23       Migraine
# 935    Daniel  Shakesby  1980-11-28       Migraine
#
# [116 rows x 4 columns]

# %%
#40.Plot a graph showing the count of patients for the reason visited the hospital.
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='EDVisits')
res = df2.groupby('ReasonForVisit')['PatientID'].size().reset_index(name='Count')
#putting the result in a dataframe
res_df=pd.DataFrame(res).sort_values('Count')
res_df
#plotting a horizontal bar graph
sns.barplot(y='ReasonForVisit', x='Count', data=res_df)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='ReasonForVisit'>

# %%
#41. Find the visit type with maximum 'No Show'.
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='AmbulatoryVisits')
r= df2.groupby('VisitType')['VisitStatus'].apply(lambda x: (x=='No Show').sum()).sort_values(ascending=False).head(1).reset_index(name ='No Show')
display(r)
# Out:
#       VisitType  No Show
# 0  Telemedicine       74

# %%
#42.Using loc , get the details of the providers where providerId is between 11 and 20 and ProviderSpecialty is Surgery.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Providers")
df =df[df['ProviderSpecialty'].isin(['Surgery'])]
df.loc[10:20]
# Out:
#     ProviderID     ProviderName ProviderSpecialty     ProviderDateOnStaff
# 10          11     Kim Kimberly           Surgery 1998-05-10 14:47:29.468
# 11          12         Sarah Ab           Surgery 1998-08-18 05:22:40.762
# 12          13  Abigail Marriot           Surgery 1998-11-08 12:25:45.705
# 13          14          Dave Yu           Surgery 1999-06-26 16:18:57.436
# 14          15  Christian Saint           Surgery 2000-08-27 00:12:40.326
# 15          16     Perry Pardon           Surgery 2001-02-13 11:49:17.862

# %%
#43.Write a regular expression to find all the digits and numbers in the string.
# For Example There are 40 students in 3 grade.
import re
RV = input("Please a write a string with digits and Numbers:")
numbers = re.findall('[0-9]+', RV)
print(numbers)
# Out:
# ['40', '3']

# %%
#44.Create a pivot table displaying average LOS based on Service and Primary Diagnosis.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
pivot = pd.pivot_table(
    data=df,
    values='ExpectedLOS',
    index=('Service','PrimaryDiagnosis'),
    aggfunc=['mean']
)
print(pivot)
# Out:
#                                            mean
#                                     ExpectedLOS
# Service          PrimaryDiagnosis
# Cardiology       AMI                  12.414202
#                  Afib                 13.162920
#                  Broken Leg            3.911826
#                  Flu                   3.970428
#                  Heart Failure        13.014044
#                  Kidney Failure        6.580273
# General Medicine Broken Leg            3.368132
#                  Diabetes              5.665298
#                  Fever                 6.803796
#                  Flu                   6.141753
#                  Hypertension          5.369365
#                  Kidney Failure        5.943163
#                  Laceration            6.771154
#                  Pneumonia             6.140270
#                  Stroke                7.173333
# Hospitalist      AMI                  13.828290
#                  Broken Leg            7.125069
# ...

# %%
#Q45 Calculate mortality by diagnosis
import pandas as pd
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Discharges")
df2=df[df["DischargeDisposition"]=='Expired']
df3=df2.groupby(["PrimaryDiagnosis", "DischargeDisposition"]).size().reset_index(name="Mortality by diagnosis")
df3
# Out:
#       PrimaryDiagnosis DischargeDisposition  Mortality by diagnosis
# 0                  AMI              Expired                       6
# 1                 Afib              Expired                       4
# 2           Broken Leg              Expired                       3
# 3             Diabetes              Expired                       9
# 4                Fever              Expired                       4
# 5                  Flu              Expired                      11
# 6        Heart Failure              Expired                      16
# 7         Hip Fracture              Expired                       3
# 8         Hypertension              Expired                      16
# 9       Kidney Failure              Expired                       2
# 10    Knee Replacement              Expired                       2
# 11          Laceration              Expired                       2
# 12                Pain              Expired                       1
# ...

# %%
#46.Write a code to split a sentence into words using regex.
#importing package
import re
Sentence = "Am working on Python Hackthon"
#Split the string at every white-space character:
x = re.split("\s", Sentence)
print(x)
# Out:
# ['Am', 'working', 'on', 'Python', 'Hackthon']

# %%
#47.Using indexing , loc to retrieve the row with maximum BloodPressureSystolic.
#Loading Dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="AmbulatoryVisits")
#retrieve the row with maximum BloodPressureSystolic
df.iloc[df['BloodPressureSystolic'].argmax()]
# Out:
# VisitID                                          933
# PatientMRN                                       884
# ProviderID                                        27
# DateofVisit                      2019-02-14 00:00:00
# DateScheduled             2019-01-22 19:26:49.163000
# VisitDepartmentID                                 12
# VisitType                               Telemedicine
# BloodPressureSystolic                          190.0
# BloodPressureDiastolic                    143.989174
# Pulse                                      74.976879
# VisitStatus                                Completed
# Name: 236, dtype: object

# %%
#48.Display the average LOS based on Service and Discharge Disposition(Maintain the column Hierarchy).
#Loading dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")

#average LOS based on Service and Discharge Disposition
result = df.groupby(['Service','DischargeDisposition'])['ExpectedLOS'].mean().reset_index(name='Average LOS')
#printing Result set
result
# Out:
#              Service DischargeDisposition  Average LOS
# 0         Cardiology              Expired     9.202626
# 1         Cardiology                 Home    12.864936
# 2         Cardiology             Transfer    11.818403
# 3   General Medicine              Expired     5.874003
# 4   General Medicine                 Home     6.105696
# 5   General Medicine             Transfer     6.116124
# 6        Hospitalist              Expired     6.775636
# 7        Hospitalist                 Home     8.009046
# 8        Hospitalist             Transfer     5.701389
# 9                ICU              Expired     9.919063
# 10               ICU                 Home    13.451158
# 11               ICU             Transfer    11.989238
# 12         Neurology              Expired     9.384312
# 13         Neurology                 Home    12.538859
# 14         Neurology             Transfer    11.469198
# 15      Orthopeadics              Expired     3.943883
# ...

# %%
#49.Retrieve the rows where SBP<140 and DBP<80.
#Loading Dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="AmbulatoryVisits")
#Applying condition
condition = (df['BloodPressureSystolic'] < 140) & (df['BloodPressureDiastolic'] < 80)
df[condition]
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 5        809         894          31  2019-03-13 2019-02-28 10:28:01.091
# 16       707         859          36  2019-03-16 2019-02-26 17:42:39.779
# 18       503         887          12  2019-01-21 2019-01-07 06:04:17.575
# 19       710         862           1  2019-03-19 2019-03-03 11:39:03.145
# 23       711         863           1  2019-03-20 2019-03-10 07:34:56.766
# ..       ...         ...         ...         ...                     ...
# 909      177         815          32  2019-02-22 2019-02-04 06:53:41.987
# 929      786         871          34  2019-03-25 2019-02-26 09:48:42.832
# 932      394         623           6  2019-02-05 2019-01-10 05:43:34.544
# 941      399         638          11  2019-02-10 2019-02-02 20:49:56.868
# 943      403         650          15  2019-02-14 2019-02-11 00:47:42.216
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# ...

# %%
#50.Which departmentID has maximum number of visits scheduled.
#Loading Dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="AmbulatoryVisits")
#calculate VisitDepartmentID group count and taking max group
df2 =df.groupby(['VisitDepartmentID'])['VisitType'].count().sort_values(ascending=False).reset_index(name='Visit Scheduled').head(1)
#printing highest count group
df2
# Out:
#    VisitDepartmentID  Visit Scheduled
# 0                 11              102

# %%
# 51.Display patient details where "ReasonForVisit" is either 'Migraine' or 'Pneumonia' and Acuity is 2 or more.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDVisits")

#Creating new dataframe for groups
#df = df.groupby(['Gender','Race'])['Spanish'].count()
condition =((df['ReasonForVisit'].isin(['Migraine', 'Pneumonia'])) & (df['Acuity']>=2))
df[condition]
# Out:
#       EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 1            12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 3            14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 11           29         29 2020-01-01 06:51:28.639 2020-01-02 05:57:01.639
# 12           30         30 2020-01-01 07:25:54.177 2020-01-01 23:30:20.151
# 13           31         31 2020-01-01 07:32:51.917 2020-01-01 19:55:46.991
# ...         ...        ...                     ...                     ...
# 1107       1027        773 2020-01-13 15:27:07.001 2020-01-14 13:27:31.778
# 1150       1104        850 2020-01-14 10:46:08.650 2020-01-14 20:52:26.031
# 1152       1106        852 2020-01-14 11:19:41.401 2020-01-15 02:47:17.353
# 1160       1122        868 2020-01-14 15:05:58.777 2020-01-15 13:53:02.550
# 1162       1124        870 2020-01-14 15:31:20.038 2020-01-15 10:28:29.406
#
#       Acuity ReasonForVisit EDDisposition
# ...

# %%
# 52.Retrieve the row with minimum DBP using sorting technique.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="AmbulatoryVisits")
df.sort_values("BloodPressureDiastolic",ascending=True).head(1)
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 757      163         801          11  2019-02-08 2019-02-07 23:41:12.181
#
#      VisitDepartmentID  VisitType  BloodPressureSystolic  \
# 757                  7  Follow Up                  120.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 757               51.695653  53.310495   Completed

# %%
# 53.Take the ReasonForVisit from user, find the number of patients admitted with that ReasonForVisit.

# User can put ReasonForVisit as Migraine,Fever,Bleeding,Pneumonia,Chest Pain etc.
RV = input("Please Enter ReasonForVisit to print the number of patients admitted with that ReasonForVisit:")
df_Ans53 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDVisits")
df_Ans53 =df_Ans53[df_Ans53['ReasonForVisit'].isin([RV])]
df_Ans53.groupby('ReasonForVisit')['PatientID'].nunique()
# Out:
# ReasonForVisit
# Fever    227
# Name: PatientID, dtype: int64

# %%
# 54.Mortality O.E.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Discharges")
DF_O= df['ExpectedMortality']
df1 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
DF_E= df1['ExpectedMortality']
df2 = pd.concat([df,df1], axis=1, join='inner')
df2['Mortality O.E'] = DF_O/DF_E
df2
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0              1          9    2018-01-01 2018-01-07 18:06:06.408
# 1            257         93    2018-01-06 2018-01-18 02:59:04.667
# 2            152        101    2018-01-07 2018-01-11 16:16:06.782
# 3            361        102    2018-01-07 2018-01-15 04:48:33.134
# 4            258        103    2018-01-07 2018-01-15 13:32:36.157
# ..           ...        ...           ...                     ...
# 715          715        716    2018-02-21 2018-03-06 03:31:05.262
# 716          698        723    2018-02-22 2018-02-26 15:09:02.584
# 717          704        724    2018-02-22 2018-02-27 07:59:32.385
# 718          716        733    2018-02-22 2018-03-05 12:31:55.958
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#     DischargeDisposition           Service PrimaryDiagnosis ExpectedLOS  \
# 0                Expired        Cardiology              AMI    9.646857
# ...

# %%
# 55.Create a bar chart on service & expected length of stay.

df_Ans55 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")

df_Ans55=df_Ans55.groupby('Service')['ExpectedLOS'].size()

plt.title("Service")
plt.xlabel("Service")
plt.ylabel("Sum of ExpectedLOS")
df_Ans55.plot(kind="bar",figsize=(15, 8))
# Out:
# <AxesSubplot:title={'center':'Service'}, xlabel='Service', ylabel='Sum of ExpectedLOS'>

# %%
# 56. Count of canceled status.
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='AmbulatoryVisits')
res= df2['VisitStatus'].apply(lambda x: (x=='Canceled')).sum()
print('Count of Canceled status:', res)
# Out:
# Count of Canceled status: 60

# %%
#57. Find the age prone to get stroke.
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='Patients')
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='Discharges')
#joining two sheets from the dataset
df = pd.concat([df1,df2], axis =1, join='inner')
#finding Age from date of birth
from dateutil.relativedelta import relativedelta
df['Age'] = [relativedelta(pd.Timestamp('now'), d).years for d in df['DateOfBirth']]
#applying the condition
df=df[df.PrimaryDiagnosis == 'Stroke']
#displaying the output
df[['Age','PrimaryDiagnosis']].sort_values('Age').tail(1)
# Out:
#      Age PrimaryDiagnosis
# 472   62           Stroke

# %%
#58. Display total count of patients service wise based on gender.
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='Patients')
df2=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='Discharges')
df = pd.concat([df1,df2], axis =1, join='inner')
df = df.groupby(['Service','Gender'])['PatientID'].size().reset_index(name='Patient_count')
df
# Out:
#              Service  Gender  Patient_count
# 0         Cardiology  Female             34
# 1         Cardiology    Male             61
# 2   General Medicine  Female             99
# 3   General Medicine    Male            164
# 4        Hospitalist  Female             54
# 5        Hospitalist    Male             47
# 6                ICU  Female             68
# 7                ICU    Male             83
# 8          Neurology  Female             31
# 9          Neurology    Male             34
# 10      Orthopeadics  Female             21
# 11      Orthopeadics    Male             24

# %%
#59. Create a dataframe by splitting provider name to firstname and lastname with names for the columns.
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='Providers')
#Convert the dataframe column to list and split the list
df1.ProviderName.str.split().tolist()
#Convert the splitted list into dataframe.
df2 = pd.DataFrame(df1.ProviderName.str.split().tolist(), columns="FirstName LastName".split())
print(df2)
# Out:
#     FirstName  LastName
# 0       Sally       Sue
# 1        Mike     Myers
# 2      Jordan   Michael
# 3         Ted     Texas
# 4         Ala      Bama
# 5       Harry      Kane
# 6       Barry       Bar
# 7         Ted     Green
# 8         Ted     Black
# 9        Fred       Man
# 10        Kim  Kimberly
# 11      Sarah        Ab
# 12    Abigail   Marriot
# 13       Dave        Yu
# 14  Christian     Saint
# 15      Perry    Pardon
# 16       Kent   Kendall
# 17       Ryan     Kevin
# 18      Tyler    Conner
# 19     Bailey    Barret
# 20      Megan     Bonco
# 21     Joesph    Walter
# 22     Walter      King
# 23       Luke      Long
# 24     Justin      Time
# 25       Mike    Joseph
# 26    Bridget    Brenda
# 27     Brenda      Bing
# 28   Chandler      Bing
# 29     Joesph      Ross
# 30     Dwight     Scott
# 31    Michael   Halpert
# 32     Pamela      Ding
# 33       Tony     Creed
# 34    Phyllis   Stanley
# 35      Holly       Hue
# 36      Trent       Tye
# ...

# %%
#60. Find the list of patients whose ExpectedLOS is greater than the value given by the user.
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='Discharges')
user_input = int(input('Enter the value of LOS: '))
res=df1[df1['ExpectedLOS'].apply(lambda x: (x > user_input))]
res[['PatientID','ExpectedLOS']]
# Out:
#      PatientID  ExpectedLOS
# 3          102    12.794536
# 12         134    16.225126
# 23         176    14.348074
# 24         178    15.183750
# 25         184    13.910330
# ..         ...          ...
# 699        645    14.981831
# 703        655    13.152834
# 704        661    12.513682
# 705        672    12.420606
# 718        733    13.323413
#
# [187 rows x 2 columns]

# %%
#61 Plot a graph by multiplotting on the same canvas  (Take any set of x & y values).
import matplotlib.pyplot as plt
import numpy as np
import math
X = np.arange(0, math.pi*2, 0.05)
y = np.sin(X)
z = np.cos(X)
plt.plot(X, y, color='r', label='sin')
plt.plot(X, z, color='g', label='cos')
plt.xlabel("Angle")
plt.ylabel("Magnitude")
plt.title("Sine and Cosine functions")
plt.legend()
plt.show()

# %%
#62 Display the data for all 'White Female' patients above the age of 50
import pandas as pd
import numpy as np
df = pd.DataFrame(pd.read_excel("HospitalDatabase .xlsx"))
from dateutil.relativedelta import relativedelta
df['age'] = [relativedelta(pd.Timestamp.now(), d).years for d in df['DateOfBirth']]
df1=df[(df.age >= 50) & (df.Race == 'White') & (df.Gender == 'Female')]
df1
# Out:
#      PatientID  FirstName   LastName             DateOfBirth  Gender   Race  \
# 25          26      Sally       Bing 1972-08-03 00:05:39.560  Female  White
# 28          29        Ted      Scott 1967-12-09 05:01:37.892  Female  White
# 30          31      Harry       Ding 1960-10-08 01:42:51.212  Female  White
# 33          34        Ted        Hue 1960-11-28 18:05:11.459  Female  White
# 34          35       Fred        Tye 1966-04-14 06:01:07.169  Female  White
# ..         ...        ...        ...                     ...     ...    ...
# 865        866   Jermayne    Lowndes 1970-12-09 04:49:48.933  Female  White
# 866        867       Gail        Inc 1967-03-10 08:18:47.908  Female  White
# 867        868        Des  Heindrick 1969-08-15 11:05:30.165  Female  White
# 869        870      Hauck    Rubbens 1963-11-16 03:31:38.929  Female  White
# 873        874  Schroeder   McGarvey 1971-12-09 11:56:22.068  Female  White
#
#     Language  age
# 25   Spanish   50
# ...

# %%
#Q 63 Using loc, retrieve the firstname and lastname of patients between indices 101 and 200
df = pd.DataFrame(pd.read_excel("HospitalDatabase .xlsx"))
#retrieving the firstname and lastname using iloc
df.iloc[101:200,1:3]
# Out:
#     FirstName    LastName
# 101     Gipsy    Frankton
# 102    Jethro      Wharin
# 103       Viv     Aylward
# 104     Swift   Dreschler
# 105     Fadel  Jacquemard
# ..        ...         ...
# 195  Cathlene     Kidwell
# 196      Noam    Laguerre
# 197      Arie     Bayless
# 198    Janaye     O'Mohun
# 199      Fonz       Group
#
# [99 rows x 2 columns]

# %%
# Q 64 Using numpy functions, multiply the following arrays
import numpy as np
a=np.arange(6).reshape(2,3)
b=np.arange(6).reshape(3,2)
print(np.matmul(a,b))
# Out:
# [[10 13]
#  [28 40]]

# %%
#Q65 Get the  number of patients based on service and primary diagnosis.
import pandas as pd
df= pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
df=df.groupby(["PrimaryDiagnosis", "Service"]).size().reset_index(name="Number of Patients Admitted")
df
# Out:
#       PrimaryDiagnosis           Service  Number of Patients Admitted
# 0                  AMI        Cardiology                           40
# 1                  AMI       Hospitalist                            1
# 2                  AMI               ICU                            5
# 3                  AMI         Neurology                            2
# 4                 Afib        Cardiology                           10
# 5                 Afib               ICU                            1
# 6           Broken Leg        Cardiology                            3
# 7           Broken Leg  General Medicine                            3
# 8           Broken Leg       Hospitalist                            3
# 9             Diabetes  General Medicine                           38
# 10            Diabetes       Hospitalist                           26
# 11               Fever  General Medicine                           13
# ...

# %%
#66 np.arange(1,31).reshape(6,5), find array slicing to get the elements 4,5,24,25,29,30.
arr =np.arange(1,31).reshape(6,5)
print(arr[0, 3:5])
print(arr[4, 3:5])
print(arr[5, 3:5])
# Out:
# [4 5]
# [24 25]
# [29 30]

# %%
#67 Make a pivot table by the no. of patients from the admission date till discharge date.

#Loading dataset

df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")

#Creating Pivot
pivot = pd.pivot_table(

    data = df,
    index = ['AdmissionDate', pd.to_datetime(df["DischargeDate"]).dt.date ],
    #columns = pd.to_datetime(df["DischargeDate"]).dt.date,
    values ='PatientID' ,
    aggfunc=['count']
)

print(pivot)
# Out:
#                                 count
#                             PatientID
# AdmissionDate DischargeDate
# 2018-01-01    2018-01-04            3
#               2018-01-05            2
#               2018-01-06            1
#               2018-01-07            3
#               2018-01-08            1
# ...                               ...
# 2018-02-22    2018-03-05            1
#               2018-03-06            1
#               2018-03-07            4
#               2018-03-08            2
#               2018-03-10            2
#
# [459 rows x 1 columns]

# %%
#68.Display the data where actual LOS is greater than expected LOS.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")

df1 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Discharges")
df2 = pd.concat([df,df1], axis=1, join='inner')
condition = (df1['ExpectedLOS'] > df['ExpectedLOS'])
df2[condition]
# Out:
#      AdmissionID  PatientID  AdmissionDate           DischargeDate  \
# 0            389          1     2018-01-01 2018-01-04 19:59:31.391
# 1            635          2     2018-01-01 2018-01-04 21:28:51.898
# 2            606          3     2018-01-01 2018-01-04 22:28:23.672
# 3            587          5     2018-01-01 2018-01-05 05:47:04.933
# 12            18         14     2018-01-18 2018-01-25 14:43:35.285
# ..           ...        ...            ...                     ...
# 705          106        728     2018-02-22 2018-02-28 10:20:26.683
# 711          515        734     2018-02-22 2018-03-06 14:14:35.824
# 713          304        736     2018-02-22 2018-03-07 17:30:19.110
# 717          509        740     2018-02-22 2018-03-08 09:27:18.377
# 718          605        741     2018-02-22 2018-03-10 06:06:12.068
#
#     DischargeDisposition           Service PrimaryDiagnosis ExpectedLOS  \
# 0                   Home       Hospitalist   Kidney Failure    6.717771
# ...

# %%
# 69.Details of the patients whose firstname or lastname contains string "lau" , should be case insensitive.

#Loading dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")

#Condition to print patients

condition =(( df["FirstName"].str.contains('lau', case=False)) | (df["LastName"].str.contains('lau', case=False)))
df[condition]
# Out:
#      PatientID FirstName   LastName             DateOfBirth  Gender  \
# 282        283    Lauren     Gaskal 1962-05-08 01:54:00.111  Female
# 322        323    Lauren      Foort 1960-06-23 20:07:53.045  Female
# 369        370    Zulauf  Ellingham 1982-12-17 16:27:56.391  Female
# 382        383    Zulauf        LLC 1969-03-16 07:48:49.338  Female
# 454        455    Zulauf      Alvar 1961-10-02 08:24:17.334  Female
# 463        464    Zulauf     Manske 1965-06-22 02:49:28.667  Female
# 818        819    Zulauf   Bitcheno 1967-04-02 07:17:53.635  Female
# 830        831    Zulauf  O'Shavlan 1970-05-17 08:09:28.988  Female
# 850        851     Lemmy    Klausen 1973-06-18 06:19:43.475  Female
# 906        907  Jerrilyn    Klausen 1979-09-04 13:05:57.870    Male
# 910        911    Zulauf     Orbine 1973-06-26 03:13:50.449    Male
#
#                        Race Language
# 282  Black/African-American  English
# 322                   White  English
# ...

# %%
#70.Plot a graph to show the distribution of expected mortality.
#Reading dataset
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")

#plot distribution of values in points column using histogram
plt.title("distribution of expected mortality ")
df['ExpectedMortality'].plot(kind='hist', edgecolor='black',color = 'y')
# Out:
# <AxesSubplot:title={'center':'distribution of expected mortality '}, ylabel='Frequency'>

# %%
# 71.Create a visualization on the count of patients based on primary diagnosis.
df_Ans_71 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
df_Ans_71['PrimaryDiagnosis']
df_Ans_71['PrimaryDiagnosis'].value_counts().plot(kind='bar');

# %%
#72.List male patients over the age of 60 who have undergone surgery from January-March 2019.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")
from dateutil.relativedelta import relativedelta
df['age'] = [relativedelta(pd.Timestamp.now(), d).years for d in df['DateOfBirth']]
#df_g = df.query('Gender == "Male"  & age>60 ')
df1 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Providers")
df3 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="AmbulatoryVisits")
#Combining two datasets
df2 = pd.concat([df,df1,df3], axis=1, join='inner')
df_g = df2.query('Gender == "Male"  & age>60 & ProviderSpecialty == "Surgery"')
#df_g
start, end = pd.to_datetime(["1JAN2019:00:00:00", "31MAR2019:00:00:00"],
                            format='%d%b%Y:%H:%M:%S')
dataset = df_g[
    (df_g['DateScheduled'] >= start) &
    (df_g['DateScheduled'] <= end)
]
print(dataset)
# Out:
# Empty DataFrame
# Columns: [PatientID, FirstName, LastName, DateOfBirth, Gender, Race, Language, age, ProviderID, ProviderName, ProviderSpecialty, ProviderDateOnStaff, VisitID, PatientMRN, ProviderID, DateofVisit, DateScheduled, VisitDepartmentID, VisitType, BloodPressureSystolic, BloodPressureDiastolic, Pulse, VisitStatus]
# Index: []
#
# [0 rows x 23 columns]

# %%
# 73.Delete the column 'DischargeDispostion' iteratively.
df_Ans73=pd.read_excel("HospitalDatabase .xlsx",sheet_name="ReAdmissionRegistry")
for col in df_Ans73.columns:
    if 'DischargeDisposition' in col:
        del df_Ans73[col]
df_Ans73
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0            389          1    2018-01-01 2018-01-04 19:59:31.391
# 1            635          2    2018-01-01 2018-01-04 21:28:51.898
# 2            606          3    2018-01-01 2018-01-04 22:28:23.672
# 3            587          5    2018-01-01 2018-01-05 05:47:04.933
# 4            640          6    2018-01-01 2018-01-05 14:18:30.029
# ..           ...        ...           ...                     ...
# 715          521        738    2018-02-22 2018-03-07 21:22:10.061
# 716          548        739    2018-02-22 2018-03-08 02:43:18.749
# 717          509        740    2018-02-22 2018-03-08 09:27:18.377
# 718          605        741    2018-02-22 2018-03-10 06:06:12.068
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#               Service PrimaryDiagnosis  ExpectedLOS  ExpectedMortality  \
# 0         Hospitalist   Kidney Failure     6.717771           0.010046
# ...

# %%
# 74.Get the list of ReasonForVisit.
df_Ans74 = pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDVisits")
print("---List of ReasonForVisit---")
print("")
print(df_Ans74['ReasonForVisit'].unique())
# Out:
# ---List of ReasonForVisit---
#
# ['Stomach Ache' 'Migraine' 'Chest Pain' 'Bleeding' 'Car Accident'
#  'Pneumonia' 'Fever' 'Shortness of Breath' 'Gun Shot' 'Accident'
#  'Laceration' 'Intoxication' 'Cough']

# %%
# 75 .Calculate the time spent in ED Department for each visit.
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDUnique")
df['Time Spent in Hour'] = (df['EDDischargeTime'] - df['VisitDate']).astype('timedelta64[h]')
#df1=df[['PatientID','EDVisitID','Time Spent in Hour']]
df
# Out:
#      EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 0            1          1 2020-01-01 00:00:00.000 2020-01-01 11:20:22.924
# 1           12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 2           13         13 2020-01-01 03:09:24.701 2020-01-01 05:00:20.852
# 3           14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 4           15         15 2020-01-01 03:46:32.698 2020-01-01 06:24:52.741
# ..         ...        ...                     ...                     ...
# 940       1183        929 2020-01-15 10:38:42.570 2020-01-16 02:31:52.023
# 941       1186        932 2020-01-15 11:52:37.540 2020-01-16 10:19:41.570
# 942       1187        933 2020-01-15 12:11:11.678 2020-01-15 16:41:15.223
# 943       1188        934 2020-01-15 12:21:46.006 2020-01-15 18:32:21.060
# 944       1189        935 2020-01-15 12:51:14.875 2020-01-15 23:40:41.456
#
#      Acuity ReasonForVisit EDDisposition  Time Spent in Hour
# ...

# %%
#76 Reverse the string without using inbuilt functions.
str = input("Enter a string value: ")
print('Reversed String is: ',str[::-1])
# Out:
# Reversed String is:  ljk

# %%
#77.Create a bar chart by making list on Acuity & EDDisposition column (with no duplicates) & make the hatchs onto the bar by using set_hatch() method.
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='EDVisits')
L1=(df1['Acuity'].unique())
print(L1)
L2 =(df1['EDDisposition'].unique())
print(L2)

plt.title('Acuity Vs EDDisposition')
plt.xlabel('Acuity')
plt.ylabel('EDDisposition')
patterns = ['','x','//','x','//']
bars = plt.bar(range(len(L1)),L1, hatch='x',facecolor='red',edgecolor='black')
for bar,pattern in zip(bars,patterns):
    bar.set_hatch(pattern)
#plt.show()
#y2 = np.ones(y1.shape) * 4
#fig = plt.figure()
#axs = fig.subplot_mosaic([['bar1', 'patches'], ['bar2', 'patches']])
#axs['bar1'].bar(x, y1, edgecolor='black', hatch="/")
#axs['bar1'].bar(x, y2, bottom=y1, edgecolor='black', hatch='//')

#axs['bar2'].bar(x, y1, edgecolor='black', hatch=['--', '+', 'x', '\\'])
#axs['bar2'].bar(x, y2, bottom=y1, edgecolor='black', hatch=['*', 'o', 'O', '.'])
# Out:
# [1 2 3 4 5]
# ['Admitted' 'Discharged']

# %%
#78. Find reasonForVisit with highest count of acuity 5 patients.
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='EDVisits')
df2=df1[df1['Acuity']==5]
df2 = df2[['ReasonForVisit','Acuity']]
df3 = df2.groupby('ReasonForVisit')['Acuity'].apply(lambda x: (x== 5).sum()).sort_values(ascending=False).head(1)
df3
# Out:
# ReasonForVisit
# Chest Pain    61
# Name: Acuity, dtype: int64

# %%
#79 Which PrimaryDiagnosis has the biggest difference between maximum and minimum Expected LOS?
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='Discharges')
res=((df1.groupby('PrimaryDiagnosis')['ExpectedLOS'].max()) - (df1.groupby('PrimaryDiagnosis')['ExpectedLOS'].min())).sort_values(ascending=False).head(1).reset_index(name ='LOS Difference')
res
# Out:
#   PrimaryDiagnosis  LOS Difference
# 0        Pneumonia        14.83426

# %%
#80 Write a code snippet to print different ProviderSpecialty ( use groupby and get the list of the groups).
df1=pd.read_excel("HospitalDatabase .xlsx", sheet_name ='Providers')
ls =(df1.groupby(['ProviderSpecialty']).size()).reset_index(name='ProviderCount')
ls['ProviderSpecialty']
# Out:
# 0     Cardiology
# 1     Pediatrics
# 2    PrimaryCare
# 3        Surgery
# Name: ProviderSpecialty, dtype: object
